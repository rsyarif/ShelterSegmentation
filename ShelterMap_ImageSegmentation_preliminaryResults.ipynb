# %% [markdown]
# # Image Segmentation : Shelter Map Identification

# %%
# %reload_ext autoreload
# %autoreload 2

import platform
print('Running on python version:',platform.python_version())

import os
import numpy as np
import train as T
import predict as P
from preprocessing.data import create_train_data, create_test_data, plot_data, plot_predict
from resources.plot_results import plot_loss_epoch

import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Running on python version: 3.6.6
# Using TensorFlow backend.

# %%
data_path = '/Users/rizki/Documents/Projects/ShelterSegmentation_take2/shelterdata_forTESTING/180505_v1'

# %%
plot_data(data_path,sample='train',showNumSample=4)
# Out:
# sample train data:

# %% [markdown]
# ### Available models: 'unet','flatunet', 'unet64filters', or 'unet64batchnorm'

# %%
log_loss_file_path='/Users/rizki/Documents/Projects/ShelterSegmentation_take2/Results/FromAWS/Oct7-2018'
from IPython.display import Image
Image(filename=log_loss_file_path+'/log_loss_epoch_ALL.png')

# %% [markdown]
# It seems "unet64filters" seems to be performing the best.

# %% [markdown]
# ## Loss function:

# %% [markdown]
# Loss function : $$ \mathrm{ - Dice~Coeff.} = - \frac{2 |X \cap Y|}{|X| + |Y|} = - \frac{2 TP}{2TP + FP + FN}$$
#
# Dice = 1  --> identical images,
# Dice ~= 0  --> very dissimilar images.

# %%
output_path='/Users/rizki/Documents/Projects/ShelterSegmentation_take2/Results/FromAWS/Oct20-2018/shelterdata/180505_v1/output/'

# %% [markdown]
# #### U-Net

# %% [markdown]
# [Original U-Net :](https://lmb.informatik.uni-freiburg.de/people/ronneber/u-net/u-net-architecture.png)
# ![U-Net](https://lmb.informatik.uni-freiburg.de/people/ronneber/u-net/u-net-architecture.png)

# %%
plot_predict(data_path,output_path,model='unet',showNumSample=4)
# Out:
# sample unet prediction:

# %% [markdown]
# #### Mod U-Net 1

# %% [markdown]
# [Original mod-U-net](https://deepsense.ai/wp-content/uploads/2017/04/architecture_details.png)
# ![Link: mod-U-net](https://deepsense.ai/wp-content/uploads/2017/04/architecture_details.png)

# %%
plot_predict(data_path,output_path,model='flatunet',showNumSample=4)
# Out:
# sample flatunet prediction:

# %% [markdown]
# #### Mod U-Net 2: "U-Net 64 filters" : all layers have 64 kernels

# %%
plot_predict(data_path,output_path,model='unet64filters',showNumSample=4)
# Out:
# sample unet64filters prediction:

# %% [markdown]
# #### Mod U-Net 3: "U-Net 64 filters" : all layers have 64 kernels  "U-Net 64 batchnorm" : all layers have 64 kernels and batchnormalized

# %%
plot_predict(data_path,output_path,model='unet64batchnorm',showNumSample=4)
# Out:
# sample unet64batchnorm prediction:
